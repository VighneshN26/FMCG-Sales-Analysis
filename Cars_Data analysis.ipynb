# %% [markdown]
# ### cars data set analysis

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\vighnesh nirgude\OneDrive\Documents\2. Cars Data1.csv")

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 50.8+ KB

# %% [markdown]
# ### Describing Data

# %%
df.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   20.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %% [markdown]
# ### finding 6 cylinders Engine type

# %%
df[df['Cylinders']==6].head(5)
# Out:
#     Make                    Model    Type Origin DriveTrain      MSRP  \
# 0  Acura                      MDX     SUV   Asia        All  $36,945
# 3  Acura                   TL 4dr   Sedan   Asia      Front  $33,195
# 4  Acura               3.5 RL 4dr   Sedan   Asia      Front  $43,755
# 5  Acura  3.5 RL w/Navigation 4dr   Sedan   Asia      Front  $46,100
# 6  Acura   NSX coupe 2dr manual S  Sports   Asia       Rear  $89,765
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0  $33,337          3.5        6.0       265.0      17.0         23.0  4451.0
# 3  $30,299          3.2        6.0       270.0      20.0         28.0  3575.0
# 4  $39,014          3.5        6.0       225.0      18.0         24.0  3880.0
# 5  $41,100          3.5        6.0       225.0      18.0         24.0  3893.0
# 6  $79,978          3.2        6.0       290.0      17.0         24.0  3153.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 3      108.0   186.0
# ...

# %% [markdown]
# ### finding Asia originated vehicles

# %%
df[df['Origin']=='Asia'].head(6)
# Out:
#     Make                    Model   Type Origin DriveTrain      MSRP  \
# 0  Acura                      MDX    SUV   Asia        All  $36,945
# 1  Acura           RSX Type S 2dr  Sedan   Asia      Front  $23,820
# 2  Acura                  TSX 4dr  Sedan   Asia      Front  $26,990
# 3  Acura                   TL 4dr  Sedan   Asia      Front  $33,195
# 4  Acura               3.5 RL 4dr  Sedan   Asia      Front  $43,755
# 5  Acura  3.5 RL w/Navigation 4dr  Sedan   Asia      Front  $46,100
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0  $33,337          3.5        6.0       265.0      17.0         23.0  4451.0
# 1  $21,761          2.0        4.0       200.0      24.0         31.0  2778.0
# 2  $24,647          2.4        4.0       200.0      22.0         29.0  3230.0
# 3  $30,299          3.2        6.0       270.0      20.0         28.0  3575.0
# 4  $39,014          3.5        6.0       225.0      18.0         24.0  3880.0
# ...

# %% [markdown]
# ### Finding participating manufacturer country from Data set

# %%
df['Origin'].value_counts()
# Out:
# Asia      158
# USA       147
# Europe    123
# Name: Origin, dtype: int64

# %% [markdown]
# ### Finding details of particular vehicle

# %%
df[df['Make']=='Acura']
# Out:
#     Make                    Model    Type Origin DriveTrain      MSRP  \
# 0  Acura                      MDX     SUV   Asia        All  $36,945
# 1  Acura           RSX Type S 2dr   Sedan   Asia      Front  $23,820
# 2  Acura                  TSX 4dr   Sedan   Asia      Front  $26,990
# 3  Acura                   TL 4dr   Sedan   Asia      Front  $33,195
# 4  Acura               3.5 RL 4dr   Sedan   Asia      Front  $43,755
# 5  Acura  3.5 RL w/Navigation 4dr   Sedan   Asia      Front  $46,100
# 6  Acura   NSX coupe 2dr manual S  Sports   Asia       Rear  $89,765
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0  $33,337          3.5        6.0       265.0      17.0         23.0  4451.0
# 1  $21,761          2.0        4.0       200.0      24.0         31.0  2778.0
# 2  $24,647          2.4        4.0       200.0      22.0         29.0  3230.0
# 3  $30,299          3.2        6.0       270.0      20.0         28.0  3575.0
# ...

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ### count of Types of vehicles

# %%
df['Type'].value_counts()
# Out:
# Sedan            262
# SUV               60
# Sports            49
# Wagon             30
# Truck             24
# Not Available      4
# Hybrid             3
# Name: Type, dtype: int64

# %% [markdown]
# ### Finding shape of Data

# %%
df.shape
# Out:
# (432, 15)

# %% [markdown]
# ### Cleaning  Data

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
  #removing null values
df['Cylinders'].fillna(df['Cylinders'].mean(),inplace= True)
df['EngineSize'].fillna(df['EngineSize'].mean(),inplace= True)
df['Horsepower'].fillna(df['Horsepower'].mean(),inplace= True)
df['MPG_Highway'].fillna(df['MPG_Highway'].mean(),inplace= True)
df['Wheelbase'].fillna(df['Wheelbase'].mean(),inplace= True)  
df['MPG_City'].fillna(df['MPG_City'].mean(),inplace= True)
df['Weight'].fillna(df['Weight'].mean(),inplace= True)
df['Length'].fillna(df['Length'].mean(),inplace= True)

# %%
df['MSRP'].fillna("Not Available",inplace =True)
df['Make'].fillna("Not Available",inplace =True)
df['Model'].fillna("Not Available",inplace =True)
df['Origin'].fillna("Not Available",inplace =True)
df['DriveTrain'].fillna("Not Available",inplace =True)
df['Invoice'].fillna("Not Available",inplace =True)
df['Type'].fillna("Not Available",inplace =True)

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %% [markdown]
# ### count of car company

# %%
df['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Chrysler         15
# Volkswagen       15
# Mitsubishi       13
# Dodge            13
# Hyundai          12
# Jaguar           12
# Volvo            12
# Kia              11
# Mazda            11
# Lexus            11
# Pontiac          11
# Subaru           11
# Lincoln           9
# Mercury           9
# Buick             9
# Saturn            8
# Infiniti          8
# GMC               8
# Cadillac          8
# Suzuki            8
# Porsche           7
# Saab              7
# Acura             7
# Not Available     4
# Oldsmobile        3
# Jeep              3
# Land Rover        3
# MINI              2
# Scion             2
# Isuzu             2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# ### Minimum priced car

# %%
df[df['MSRP']==df['MSRP'].min()]
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP  Invoice  \
# 210  Kia  Rio 4dr manual  Sedan   Asia      Front  $10,280   $9,875
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 210         1.6        4.0       104.0      26.0         33.0  2403.0
#
#      Wheelbase  Length
# 210       95.0   167.0
